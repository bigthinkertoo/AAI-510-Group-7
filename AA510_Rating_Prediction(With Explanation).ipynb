# %% [markdown]
# # Rating Prediction Project - Amazon Reviews/Yelp Reviews
#
# Fine-tune BERT to predict star ratings (1-5) based on combined review text and summary.

# %% [markdown]
# # 1. Problem Statement and Justification
#
# Online reviews have become critical indicators of product quality as they contain a wealth of insights/information. Automatically predicting review ratings based on written content helps improve user experience, flag inconsistencies, and support business intelligence. This project focuses on predicting star ratings (1 to 5) using BERT, a transformer-based NLP model, leveraging review text and summaries.

# %% [markdown]
# **GOAL: PREDICT THE RATING(1-5 STARS) FROM REVIEW TEXT**

# %%
# Install necessary packages
#!pip install transformers datasets scikit-learn pandas torch tqdm matplotlib

# %% [markdown]
# **1. Data Preparation**
# Gather your review_text and rating pairs.
# Split into train / validation / test sets.
#
# **2. Text Preprocessing**
# Options:
# Basic: lowercasing, punctuation removal, stopwords removal, lemmatization
# Or use pre-trained models that handle this internally (e.g. transformers).
#
#
# **3: Text Representation (Vectorization)**
# Several options:
# **a) TF-Ireviews_df + regression model:**
#     Use Tfireviews_dfVectorizer to convert text → feature vectors.
#     Feed into regression model (e.g. LinearRegression, Ridge, SVR, RandomForestRegressor).
# **b) Word embeddings + regression model**
#     Use Word2Vec, GloVe, or sentence embeddings (e.g. Sentence-BERT) to convert text → vector.
#     Feed into regressor.
# **c) End-to-end transformer model (best results)**
#     Fine-tune BERT, DistilBERT, or RoBERTa to directly predict the rating from text.
#     Implement with HuggingFace Transformers.
#
# **4: Model Training**
#     Loss: Mean Squared Error (MSE) or Mean Absolute Error (MAE).
#     Evaluation: R², RMSE, MAE, etc.

# %%
# Imports
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
#from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# We are going with two different datasets(Amazon_Reviews and Yelp Reviews). Amazon_Reviews dataset is smaller in size and we
# were not sure if this will be apt for modeling and evaluating hte response. So we worked with Yelp_Reviews dataset in parallel.
#
# Workign with two datasets in parallel gave us better understanding.

# %%
file_path = "/Users/roshan_thakur/Desktop/MachineLearning/ML-Project/Datasets/Amazon-Reviews/amazon_review.csv"
reviews_df = pd.read_csv(file_path,encoding="latin")
reviews_df.head(5)
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.        4
# 1  Purchased this for my device, it worked as adv...        5
# 2  it works as expected. I should have sprung for...        4
# 3  This think has worked out great.Had a diff. br...        5
# 4  Bought it with Retail Packaging, arrived legit...        5
#
#                                   summary  unixReviewTime reviewTime  \
# 0                              Four Stars      1406073600    7/23/14
# 1                           MOAR SPACE!!!      1382659200   10/25/13
# 2               nothing to really say....      1356220800   12/23/12
# 3  Great buy at this price!!!  *** UPDATE      1384992000   11/21/13
# 4                        best deal around      1373673600    7/13/13
#
#    day_diff  helpful_yes  total_vote
# 0       138            0           0
# 1       409            0           0
# 2       715            0           0
# 3       382            0           0
# 4       513            0           0

# %%
yelp_file_path = "/Users/roshan_thakur/Desktop/MachineLearning/ML-Project/Datasets/Yelp-Reviews/Yelp-review_10k.xlsx"
yelp_df = pd.read_excel(yelp_file_path)
yelp_df.head(5)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %% [markdown]
# **Data understanding (EDA) – a graphical and non-graphical representation of relationships between the response variable and predictor
# variables.**
#
# Exploratory Data Analysis (EDA) is a critical step in understanding the structure, patterns, and relationships in the dataset. Since this
# project deals with natural language data, the EDA combines both traditional statistical exploration and NLP-specific visualizations.

# %% [markdown]
# **YELP_REVIEW DATASET**
#
# *Dropped Unnecessary Columns:*
#
# Removed metadata fields that are not useful for text-based rating prediction:
# **review_id, user_id, business_id, date, funny, and cool.**
#
# *Renamed Columns for Consistency:*
#
# Renamed the **text column --> review** to clearly indicate the content being analyzed.
# Converted the **stars column (original rating) to an integer type** and renamed it to rating.
#
# The dataset now primarily contains:
#
# **review:** the full review text (input feature)
# **rating:** the numeric star rating (target variable)

# %%
#Change column name from overall to rating for clarity
yelp_df.drop(columns=['review_id'], inplace=True)
yelp_df.drop(columns=['user_id'], inplace=True)
yelp_df.drop(columns=['business_id'], inplace=True)
yelp_df.drop(columns=['date'], inplace=True)
yelp_df.drop(columns=['funny'], inplace=True)
yelp_df.drop(columns=['cool'], inplace=True)
yelp_df = yelp_df.rename(columns={'text': 'review'})
yelp_df['rating'] = yelp_df['stars'].astype(int)
yelp_df.drop(columns=['stars'], inplace=True)

yelp_df.head(5)
# Out:
#    useful                                             review  rating
# 0       0  If you decide to eat here, just be aware it is...       3
# 1       1  I've taken a lot of spin classes over the year...       5
# 2       0  Family diner. Had the buffet. Eclectic assortm...       3
# 3       1  Wow!  Yummy, different,  delicious.   Our favo...       5
# 4       1  Cute interior and owner (?) gave us tour of up...       4

# %% [markdown]
# **AMAZON_REVIEWS DATASET**
#
# *Combined Textual Features:*
#
# Merged **summary and reviewText** into a single field named **review** to consolidate the information into one input feature.
#
# *Handled Missing Values:*
#
# Filled missing values in summary with an empty string before concatenation.
# Dropped rows with missing values in the final review or rating columns.
#
# *Renamed and Reformatted Rating:*
#
# Renamed the column **overall** to **rating**.
# Converted rating values to integer type for consistency in classification tasks.
#
# The dataset now contains only:
#
# **review:** Full textual input (summary + review text)
# **rating:** Star rating (target label)

# %%
# Combine reviewText and summary
reviews_df['summary'] = reviews_df['summary'].fillna('')
reviews_df['review'] = reviews_df['summary'] + ' ' + reviews_df['reviewText']
reviews_df['rating'] = reviews_df['overall']
reviews_df.head(5)


# Use combined_text and overall
reviews_df = reviews_df[['review', 'rating']].dropna()
reviews_df['rating'] = reviews_df['rating'].astype(int)

# %%
reviews_df.head(5)
# Out:
#                                               review  rating
# 0                              Four Stars No issues.       4
# 1  MOAR SPACE!!! Purchased this for my device, it...       5
# 2  nothing to really say.... it works as expected...       4
# 3  Great buy at this price!!!  *** UPDATE This th...       5
# 4  best deal around Bought it with Retail Packagi...       5

# %% [markdown]
# **RATING DISTRIBUTION AMAZON_REVIEWS DATASET**
#
# The Plot Shows:
# **X-axis:** Star Ratings (1 to 5)
# **Y-axis:** Number of Reviews for each rating
#
# Each bar represents the total number of reviews that received a particular star rating.
#
# The plot diagrams shows 5-star rating dominates the dataset as it is heavily skewed toward 5 Stars.
# 1-star, 2-star, and 3-star reviews are much less frequent, especially 2-star ratings which are the least represented.
# Moderate Number of 4-Star Reviews, show some variability in user satisfaction.
#
# **The dataset shows a class imbalance, with over 3,900 5-star reviews and fewer 1, 2, and 3-star reviews. 4-star reviews are moderately represented.**

# %%
# Plot rating distribution
# sort_index() ensures ratings appear in order (1, 2, 3, 4, 5)
reviews_df['rating'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Rating Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# **RATING DISTRIBUTION YELP_REVIEWS DATASET**
# The Plot Shows:
# **X-axis:** Star ratings (1 to 5)
# **Y-axis:** Count of reviews for each rating
#
# Each bar represents the total number of reviews that received a particular star rating.
#
# --> The plot diagrams shows that the 5-star rating has the highest frequency (over 220,000 reviews) which suggests a strong positive skew in user feedback.
# ---> 4-star reviews also appear in large volume, with over 100,000 entries. These reviews typically reflect positive experiences with minor drawbacks, offering more balanced and practical feedback. For a model, 4-star reviews are often semantically close to 5-star reviews, making them harder to distinguish.
# --> 1, 2-star & 3-start reviews are underrepresented. 1-, 2-, 3-star reviews are significantly fewer. However,these ratings are important as they typically represent negative sentiment and dissatisfaction.
#
# **This class imbalance may cause models to underperform on detecting dissatisfaction unless mitigated.**

# %%
# sort_index() ensures ratings appear in order (1, 2, 3, 4, 5)
yelp_df['rating'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Rating Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# **CONCLUSION**
#
# **The plot diagram revealed the counts of how many reviews exist for each rating. A balanced review dataset have evenly distributed ratings, while a skewed plot indicates imbalance. Polarization, common in product reviews, shows many 5-star and 1-star ratings but few middle ratings.**

# %% [markdown]
# **To confirm if we have data imbalance, let's calculate the exact imbalance % in the dataset.**

# %%
def print_distribution(df, title):
    print(f"\n\033[1m{title} Rating Distribution:\033[0m")
    total_reviews = len(df)
    rating_counts = df['rating'].value_counts().sort_index()
    # Calculate % per rating
    rating_percentages = (rating_counts / total_reviews) * 100
    for rating, pct in rating_percentages.items():
        print(f"Rating {rating}: {pct:.2f}% ({rating_counts[rating]} reviews)")
    return

# %%
print_distribution(reviews_df, "Amazon Reviews")
print_distribution(yelp_df, "Yelp Reviews")
# Out:
# Amazon Reviews Rating Distribution:
# Rating 1: 4.97% (244 reviews)
# Rating 2: 1.63% (80 reviews)
# Rating 3: 2.89% (142 reviews)
# Rating 4: 10.72% (527 reviews)
# Rating 5: 79.79% (3921 reviews)
#
# Yelp Reviews Rating Distribution:
# Rating 1: 10.79% (1079 reviews)
# Rating 2: 7.63% (763 reviews)
# Rating 3: 11.39% (1139 reviews)
# Rating 4: 25.74% (2574 reviews)
# Rating 5: 44.45% (4445 reviews)

# %% [markdown]
# As we can see from the plot diagram and the imbalance %, that ~80% of reviews are 5 stars. Hence we can conclude that the
# data is **highly imbalanced.** And if we decide to use the data **as-is** to train the model, the model will be strongly biased
# to predict 5 stars as it has so many examples.

# %% [markdown]
# **For LLMs and NLP models, it is very helpful to see how long the reviews are and if it needs to be truncated.**

# %% [markdown]
# **DISTRIBUTION OF REVIEW TEXT LENGTH - AMAZON REVIEWS**
# The Plot Shows:
# **X-axis:** Length of each review (in number of characters)
# **Y-axis:** Number of reviews with that approximate length
#
# Each bar represents a range (or "bin") of character lengths.
#
# **Key Observations:**
# Most reviews are short and the vast majority of reviews have fewer than 500 characters.
# This sharp left-skew indicates that many users leave brief comments (e.g., one-liners, short praises or complaints) and long reviews
# are rare.There are very few reviews longer than 1,000 characters.Some extreme outliers exist (up to ~8,500 characters),
# but they are extremely uncommon.
#
# **Right-Skewed Distribution**
# The distribution is right-skewed (positive skew), meaning most reviews are short, with a long tail of occasional long reviews.

# %% [markdown]
# **DISTRIBUTION OF REVIEW TEXT LENGTH - YELP REVIEWS**
# The Plot Shows:
# **X-axis:** Number of characters in each review.
# **Y-axis:** Number of reviews falling within each character-length range.
#
# Each bar represents a bucket of review lengths (e.g., 0–250, 250–500, etc.).
#
# **Key Observations:**
#
# Most of the reviews are short—less than 500 characters long.
# Users on Yelp tend to leave slightly longer reviews than on Amazon, often describing service, food, or ambiance in detail.
#
# Unlike Amazon’s sharper drop-off, Yelp reviews have a smoother tail.There’s a steady decline in review frequency as length increases,
# with reviews still present beyond 1,000 and even up to 4,000+ characters.
#
# **Right-Skewed Distribution**
#
# The distribution is right-skewed (positive skew), but not as extreme as Amazon’s. This suggests Yelp users are more willing to write
# medium to long-form content.

# %%
def plot_text_length_distribution(df, title):
    # Compute text length (in characters)
    df['text_length'] = df['review'].apply(len)
    total_reviews = len(df)

    # Plot histogram of text lengths
    plt.figure(figsize=(10,6))
    plt.hist(df['text_length'], bins=20, color='skyblue', edgecolor='black')
    plt.xlabel('Text Length (number of characters)')
    plt.ylabel('Number of Reviews')
    plt.title(f'Distribution of Review Text Length - {title}')

    # Add custom tick marks
    import numpy as np
    plt.xticks(np.arange(0, df['text_length'].max() + 1, 500))
    plt.yticks(np.arange(0, plt.ylim()[1] + 1, total_reviews/10))

    plt.grid(True)
    plt.show()

plot_text_length_distribution(reviews_df, "Amazon Reviews")
plot_text_length_distribution(yelp_df, "Yelp Reviews")

# %%
def print_review_length_distribution(df, title):
    # Print the percentage of reviews by length bin

    #Define bins (customize as needed)
    bins = [0, 250, 500, 1000, 2000, 10000]
    labels = ['0-250', '251-500', '501-1000', '1001-2000', '2001+']

    # Bin the review lengths
    df['length_bin'] = pd.cut(df['text_length'], bins=bins, labels=labels, right=True)

    # Calculate percentages
    bin_counts = df['length_bin'].value_counts(normalize=True).sort_index() * 100

    # Print results
    print(bin_counts)
    print("\n\033[1mTotal reviews:\033[0m", len(df), '\n')
    
print_review_length_distribution(reviews_df, "Amazon Reviews")
print_review_length_distribution(yelp_df, "Yelp Reviews")
# Out:
# Percentage of Amazon Reviews by length:
# 0-250        64.082214
# 251-500      23.768824
# 501-1000      9.605210
# 1001-2000     2.035002
# 2001+         0.508751
# Name: length_bin, dtype: float64
#
# Total reviews: 4914
#
#
# Percentage of Yelp Reviews by length:
# 0-250        29.43
# 251-500      31.46
# 501-1000     26.08
# 1001-2000    10.72
# 2001+         2.31
# Name: length_bin, dtype: float64
#
# Total reviews: 10000

# %% [markdown]
# **NOT SURE IF WE NEED THIS**
#
# The plot above shows that:
#
# 87% of the amazon reviews are under 500 characters which is very short.
# There is a long tail of long reviews which are rare but present.
#
# 60% of the yelp reviews are under 500 characters. The yelp reviews provide
# a better distribution of review lengths.
#
# The distribution is highly skewed for the amazon reviews, though not as
# much for the Yelp reviews.

# %% [markdown]
# **BALANCE THE DATASET**

# %% [markdown]
# **Why We Need to Balance the Datasets – Amazon & Yelp Reviews**
#
# Since we learned that both the Amazon and Yelp review datasets are heavily imbalanced, with a large majority of reviews being
# 4- or 5-star ratings. Lower ratings (1, 2 and 3 stars) are significantly underrepresented.
#
# Models trained on this data are likely to overpredict 5-star reviews, ignoring more critical (lower-rated) feedback.
# Minority classes (1- and 2-star reviews) contain important information often representing dissatisfaction or poor experiences that the model may fail to recognize. Evaluation metrics like accuracy may look high, but actual performance on low-rating predictions will be poor.
#
# Balancing of the Amazon and Yelp datasets was achieved using a method called **undersampling**, which equalizes the number of samples to match the smallest one, across all rating classes.

# %%
def graph_balanced_rating_distribution(df, title):
    # Compute current counts
    rating_counts = df['rating'].value_counts().sort_index()
    print("\n\033[1mOriginal rating counts:\033[0m")
    print(rating_counts)

    # Determine minimum class size
    min_count = rating_counts.min()
    print(f"\nTarget samples per class (smallest class): {min_count}")
    
    # Create a balanced dataset by ensuring each rating category has the same number of samples
    balanced_parts = []
    for rating, group in df.groupby('rating'):
        sampled = group.sample(min_count, random_state=42)
        balanced_parts.append(sampled)

    balanced_df = pd.concat(balanced_parts).reset_index(drop=True)

    # Plot the balanced rating distribution
    balanced_counts = balanced_df['rating'].value_counts().sort_index()
    print("\n\033[1mBalanced rating counts:\033[0m")
    print(balanced_counts)
    
    plt.figure(figsize=(10,6))
    balanced_counts.plot(kind='bar', color='lightblue', edgecolor='black')
    plt.xlabel('Rating')
    plt.ylabel('Number of Reviews')
    plt.title(f'Balanced Rating Distribution - {title}')
    plt.grid(True)
    plt.show()
    
    return balanced_df

balanced_reviews_df = graph_balanced_rating_distribution(reviews_df, "Amazon Reviews")
yelp_balance_reviews_df = graph_balanced_rating_distribution(yelp_df, "Yelp Reviews")
# Out:
# Original rating counts:
# 1     244
# 2      80
# 3     142
# 4     527
# 5    3921
# Name: rating, dtype: int64
#
# Target samples per class (smallest class): 80
#
# Balanced rating counts:
# 1    80
# 2    80
# 3    80
# 4    80
# 5    80
# Name: rating, dtype: int64
# Original rating counts:
# 1    1079
# 2     763
# 3    1139
# 4    2574
# 5    4445
# Name: rating, dtype: int64
#
# Target samples per class (smallest class): 763
#
# Balanced rating counts:
# 1    763
# 2    763
# 3    763
# 4    763
# 5    763
# Name: rating, dtype: int64

# %% [markdown]
# **MODELING PIPELINE**

# %% [markdown]
# Split the data into training and validation sets using train_test_split (stratified on ratings for class balance).

# %%
# Import necessary libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

balanced_df = yelp_balance_reviews_df

# Split the balanced data
X_train, X_test, y_train, y_test = train_test_split(
    balanced_df['review'],
    balanced_df['rating'],
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# **Option A — TF-IDF + Ridge Regression (Baseline)**

# %%
# Vectorize text using TF-IDF
# Set the maximum number of features to the match the length of the review text
vectorizer = TfidfVectorizer(max_features = 2000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print(vectorizer.get_feature_names_out())
# Out:
# ['00' '10' '100' ... 'yum' 'yummy' 'zero']

# %%
# Train Ridge regression model
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train_tfidf, y_train)

# Predict on test set
y_pred = ridge_model.predict(X_test_tfidf)

# Evaluate model
print("\033[1mTF-IDF + Ridge Regression Results\033[0m")
print("\033[1mR²:\033[0m", r2_score(y_test, y_pred))
print("\033[1mRMSE:\033[0m", np.sqrt(mean_squared_error(y_test, y_pred)))
print("\033[1mMAE:\033[0m", mean_absolute_error(y_test, y_pred))
# Out:
# TF-IDF + Ridge Regression Results
# R²: 0.3853981698194764
# RMSE: 1.193939747171084
# MAE: 1.0116514929909584

# %%
# Plot true vs predicted ratings
plt.scatter(y_test, y_pred, alpha=0.6)
plt.xlabel("True Rating")
plt.ylabel("Predicted Rating")
plt.title("TF-IDF + Ridge Regression: True vs Predicted Ratings")
plt.grid(True)
plt.show()

# %% [markdown]
# We see a lot of spread vertically for each true rating:
#
# Many predictions cluster around ~2 to ~4 for every true rating.The model is not confidently predicting the extreme ratings (1 or 5).
#
# For true rating = 1, many predictions are around 2-3 instead of 1.
# For true rating = 5, many predictions are around 3-4, not exactly 5.
#
# **Overall pattern**
# The model seems to have a regression to the mean behavior:
#
# Tends to predict around 2.5 to 4 regardless of input.Less confident in predicting very low or very high ratings.
#
# This is common in imbalanced datasets and when using Ridge regression (which penalizes large weights).

# %% [markdown]
# **TF-IDF WITH PROPER TEXT PREPROCESSING**

# %%
# Install NLTK if needed
#!pip install nltk

# Import libraries
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download NLTK resources (first time only)
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Define preprocessing function
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation and non-alphabetic characters
    text = re.sub(r'[^a-z\s]', '', text)
    # Tokenize
    tokens = nltk.word_tokenize(text) # Tokenize the text into words
    # Remove stop words and non-alphabetic tokens, apply lemmatization
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word.isalpha() and word not in stop_words and len(word) > 2]

    #tokens = text.split()
    # Remove stopwords and lemmatize
    #tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    # Join back to string
    return ' '.join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jim.mccarthy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jim.mccarthy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Apply preprocessing to train and test text
X_train_processed = X_train.apply(preprocess_text)
X_test_processed = X_test.apply(preprocess_text)

# %%
# Vectorize preprocessed text
vectorizer = TfidfVectorizer(max_features=500)
X_train_tfidf = vectorizer.fit_transform(X_train_processed)
X_test_tfidf = vectorizer.transform(X_test_processed)

# Train Ridge regression model
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train_tfidf, y_train)

# Predict on test set
y_pred_preprocessed = ridge_model.predict(X_test_tfidf)

# Evaluate model
print("TF-IDF + Ridge (with preprocessing) Results")
print("R²:", r2_score(y_test, y_pred_preprocessed))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_preprocessed)))
print("MAE:", mean_absolute_error(y_test, y_pred_preprocessed))
# Out:
# TF-IDF + Ridge (with preprocessing) Results
# R²: 0.5644026904691261
# RMSE: 0.93371369170497
# MAE: 0.7475544934675654

# %%
# Plot true vs predicted ratings
plt.scatter(y_test, y_pred, alpha=0.6)
plt.xlabel("True Rating")
plt.ylabel("Predicted Rating")
plt.title("TF-IDF + Ridge (with preprocessing): True vs Predicted Ratings")
plt.grid(True)
plt.show()

# %% [markdown]
# **Sentence-BERT + RandomForestRegressor (Better semantics)**

# %%
#import sys
#!{sys.executable} -m pip install sentence-transformers

# %%
# Install SentenceTransformers if not already installed
#%pip install sentence-transformers

# Import necessary libraries
from sentence_transformers import SentenceTransformer 
from sklearn.ensemble import RandomForestRegressor

# Load Sentence-BERT model
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight, fast model
# Out:
# e:\ProgramData\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
X_train_sample = X_train.tolist()[:10000]  # Sample for faster processing
X_test_sample = X_test.tolist()[:10000]  # Sample for faster processing
y_train_sample = y_train.tolist()[:10000]  # Sample for faster processing
y_test_sample = y_test.tolist()[:10000]  # Sample for faster processing
y_pred_sample = y_pred.tolist()[:10000]  # Sample for faster processing

# %%
# Encode training and test sentences
X_train_embeddings = sbert_model.encode(X_train_sample, batch_size=64, show_progress_bar=True)
X_test_embeddings = sbert_model.encode(X_test_sample, batch_size=64, show_progress_bar=True)

# %%
# Train Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train_embeddings, y_train_sample)

# Predict on test set
y_pred_rf = rf_model.predict(X_test_embeddings)

# %%
# Evaluate model
print("Sentence-BERT + RandomForestRegressor Results")
print("R²:", r2_score(y_test_sample, y_pred_rf))
print("RMSE:", np.sqrt(mean_squared_error(y_test_sample, y_pred_rf)))
print("MAE:", mean_absolute_error(y_test_sample, y_pred_rf))
# Out:
# Sentence-BERT + RandomForestRegressor Results
# R²: 0.48966120620133446
# RMSE: 1.016560239238187
# MAE: 0.8354239999999999

# %%
# Plot true vs predicted ratings
plt.scatter(y_test_sample, y_pred_rf, alpha=0.6)
plt.xlabel("True Rating")
plt.ylabel("Predicted Rating")
plt.title("Sentence-BERT + RandomForest: True vs Predicted Ratings")
plt.grid(True)
plt.show()

# %% [markdown]
# Observations:
#
# For higher true ratings (4, 5), the predicted ratings tend to be higher.
# For lower true ratings (1, 2), the predictions are lower.
# For true rating 1:
# Predicted ratings mostly between ~1.7 to ~3.5.
# The model struggles to predict exactly 1.
# For true rating 5:
# Predicted ratings mostly between ~2.9 to ~4.3.
# The model under-predicts the highest ratings.
# The model shows regression to the mean behavior:
# Many predictions cluster around ~2.5 to ~3.5, even for extreme true ratings.

# %%
# Calculate metrics
# Sentence-BERT + RandomForestRegressor
r2_rf = r2_score(y_test_sample, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test_sample, y_pred_rf))
mae_rf = mean_absolute_error(y_test_sample, y_pred_rf)

# TF-IDF + Ridge Regression
r2_ridge = r2_score(y_test, y_pred)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred))
mae_ridge = mean_absolute_error(y_test, y_pred)


# TF-IDF + Ridge (with preprocessing) Results
r2_ridge_preprocessing = r2_score(y_test, y_pred)
rmse_ridge_preprocessing = np.sqrt(mean_squared_error(y_test, y_pred))
mae_ridge_preprocessing = mean_absolute_error(y_test, y_pred)

# Create DataFrame
results_df = pd.DataFrame({
    'Model': ['Sentence-BERT + RandomForestRegressor', 'TF-IDF + Ridge Regression', 'TF-IDF + Ridge Regression(preprocessing)'],
    'R2': [r2_rf, r2_ridge, r2_ridge_preprocessing],
    'RMSE': [rmse_rf, rmse_ridge, rmse_ridge_preprocessing],
    'MAE': [mae_rf, mae_ridge, mae_ridge_preprocessing]
})

# Display DataFrame
print(results_df)
# Out:
#                                       Model        R2     RMSE       MAE
# 0     Sentence-BERT + RandomForestRegressor  0.489661  1.01656  0.835424
# 1                 TF-IDF + Ridge Regression  0.661019  0.82368  0.657328
# 2  TF-IDF + Ridge Regression(preprocessing)  0.661019  0.82368  0.657328

# %%
#!pip install transformers datasets

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Round predictions to nearest integer between 1 and 5
y_pred_rounded = np.clip(np.round(y_pred), 1, 5)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_rounded, labels=[1, 2, 3, 4, 5])

# Plot confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[1,2,3,4,5],
            yticklabels=[1,2,3,4,5])
plt.xlabel("Predicted Rating")
plt.ylabel("True Rating")
plt.title("Confusion Matrix (Rounded Ratings)")
plt.show()

# %% [markdown]
# **Ratings 1 and 2:**
# True rating 1 → 14 predicted as 2, 7 as 3 → model struggles to predict 1-star correctly. Only 1 correctly predicted as 1.
#
# The model tends to underestimate how bad the review is.
#
# True rating 2 → 8 predicted as 2 → this is decent.
#
# But 8 predicted as 3 → confused between 2 and 3.
#
# 👉 Conclusion → Model struggles to predict very low ratings (1, 2). Tends to shift them toward the middle (3).
#
# **Ratings 3:**
# True rating 3 → 8 predicted correctly.
#
# 2 predicted as 4 → some tendency to slightly overpredict.
#
# 👉 Conclusion → Model is reasonably accurate at predicting 3-star reviews.
#
# **Ratings 4:**
# True rating 4 → 6 correctly predicted as 4.
#
# 5 predicted as 3 → tendency to underpredict 4-star reviews a bit.
#
# **Ratings 5:**
# True rating 5 → only 2 predicted correctly.
#
# 10 predicted as 3, 6 as 4 → model strongly underpredicts 5-star reviews.
#
# 👉 Conclusion → Model struggles with 5-star reviews — tends to push them toward 3 or 4.
